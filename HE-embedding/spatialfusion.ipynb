# %% [markdown]
# # SpatialFusion

# %%
import zarr

zarr_path = "/path/to/Xenium_Prime_Ovarian_Cancer_FFPE_XRrun_xe_outs/cell_features/cell_feature_matrix.zarr"

store = zarr.open(zarr_path, mode='r')
print(store.tree())
# Out:
# ---------------------------------------------------------------------------
# PathNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 5
#       1 import zarr
#       3 zarr_path = "/path/to/Xenium_Prime_Ovarian_Cancer_FFPE_XRrun_xe_outs/cell_features/cell_feature_matrix.zarr"
# ----> 5 store = zarr.open(zarr_path, mode='r')
#       6 print(store.tree())
#
# File /opt/miniconda3/envs/spatialfusion/lib/python3.10/site-packages/zarr/convenience.py:137, in open(store, mode, zarr_version, path, **kwargs)
#     135     return open_group(_store, mode=mode, **kwargs)
#     136 else:
# --> 137     raise PathNotFoundError(path)
#
# PathNotFoundError: nothing found at path ''
